# %% [markdown]
# # ClippyMe - Google Colab Deployment
# Ye notebook aapke project ko Google Colab ke free GPU par run karegi.

# %%
# STEP 1: Apna GitHub repo clone karein
# Yahan YOUR_USERNAME aur YOUR_REPO_NAME ko apne github link se change karein
# !git clone https://github.com/YOUR_USERNAME/YOUR_REPO_NAME.git
# %cd YOUR_REPO_NAME

# %%
# STEP 2: Zaroori software aur packages install karein (isme thoda time lagega)
# !apt-get update
# !apt-get install -y ffmpeg libgl1 libglib2.0-0 libcairo2
# !curl -fsSL https://deb.nodesource.com/setup_20.x | bash -
# !apt-get install -y nodejs
# !curl -fsSL -o /usr/local/bin/auto-editor https://github.com/WyattBlue/auto-editor/releases/download/30.5.0/auto-editor-linux-x86_64
# !chmod +x /usr/local/bin/auto-editor

# %%
# STEP 3: Python aur Frontend libraries install karein aur build karein
# !pip install -r requirements.lock
# !pip install -e .
# !npm --prefix dashboard ci || npm --prefix dashboard install
# !npm --prefix dashboard run build
# !npm install -g localtunnel

# %%
# STEP 4: Server Start Karein aur Live URL generate karein
import urllib.request
print("==========================================================")
print("⚠️ Tunnel Password (IP) ye hai:", urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip())
print("Isko copy karein aur jab localtunnel link open karein, tab isey paste karein.")
print("==========================================================")

# !lt --port 8000 & uvicorn clippyme.api.app:app --host 0.0.0.0 --port 8000
